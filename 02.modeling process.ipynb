# %% [markdown]
# 02. 머신러닝 모델링 프로세스

# %%
pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\miniforge3\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.0-cp310-cp310-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.1-cp310-cp310-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/11.0 MB 26.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.2/11.0 MB 40.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 44.1 MB/s eta 0:00:01
#    --------------------------- ------------ 7.5/11.0 MB 48.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.8/11.0 MB 35.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.0 MB 30.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 30.9 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 29.7 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    --------------------------------------- 301.8/301.8 kB 19.4 MB/s eta 0:00:00
# Downloading scipy-1.14.0-cp310-cp310-win_amd64.whl (44.8 MB)
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    - -------------------------------------- 1.3/44.8 MB 40.6 MB/s eta 0:00:02
#    - -------------------------------------- 1.6/44.8 MB 20.0 MB/s eta 0:00:03
#    -- ------------------------------------- 2.5/44.8 MB 17.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.2/44.8 MB 30.2 MB/s eta 0:00:02
#    ------ --------------------------------- 7.4/44.8 MB 33.8 MB/s eta 0:00:02
#    -------- ------------------------------- 9.6/44.8 MB 36.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 11.8/44.8 MB 43.7 MB/s eta 0:00:01
#    ------------ --------------------------- 13.9/44.8 MB 50.4 MB/s eta 0:00:01
#    ------------- -------------------------- 14.7/44.8 MB 43.7 MB/s eta 0:00:01
#    --------------- ------------------------ 17.1/44.8 MB 43.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 18.0/44.8 MB 40.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 18.4/44.8 MB 32.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 20.0/44.8 MB 31.2 MB/s eta 0:00:01
#    ------------------- -------------------- 22.1/44.8 MB 32.7 MB/s eta 0:00:01
#    --------------------- ------------------ 24.2/44.8 MB 32.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 26.5/44.8 MB 36.3 MB/s eta 0:00:01
#    -------------------------- ------------- 29.5/44.8 MB 54.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 32.3/44.8 MB 54.7 MB/s eta 0:00:01
#    ------------------------------- -------- 34.9/44.8 MB 65.6 MB/s eta 0:00:01
#    --------------------------------- ------ 37.8/44.8 MB 65.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.7/44.8 MB 59.5 MB/s eta 0:00:01
#    ------------------------------------- -- 42.0/44.8 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.8 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 36.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.1 scipy-1.14.0 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\miniforge3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\miniforge3\lib\site-packages)

# %%
from sklearn.datasets import load_iris

iris = load_iris()

iris_feature = iris.data
iris_target = iris.target

# %% [markdown]
# 데이터를 불러 왔으면 반드시 shape을 확인

# %%
print("feature shape : {}".format(iris_feature.shape))
print("target shape : {}".format(iris_target.shape))
# Out:
# feature shape : (150, 4)
# target shape : (150,)

# %%
import pandas as pd

feature_names = iris.feature_names

iris_df = pd.DataFrame(
    data=iris_feature,
    columns=feature_names
)

iris_df['target'] = iris_target
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# 분류 문제에서 가장 중요한 확인할 내용 : 타깃의 개수 확인(비율 확인)

# %%
iris_df['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# ## 학습 데이터 / 테스트 데이터 분리

# %%
from sklearn.model_selection import train_test_split

X_train, X_test , y_train , y_test = train_test_split(
    iris_df.drop("target", axis = 1), #Feature Matrix
    iris_df['target'], #Target Vector
    test_size = 0.2, # 테스트 세트의 비율. 보통은 0.2-0.3
    random_state = 11 #랜덤 시드 고정값
)

print("훈련 데이터의 shape : {}".format(X_train.shape))
print("테스트 데이터의 shape : {}".format(X_test.shape))
# Out:
# 훈련 데이터의 shape : (120, 4)
# 테스트 데이터의 shape : (30, 4)

# %% [markdown]
# ## 모델 훈련

# %% [markdown]
# 의사결정나무 분류기 사용

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# 모델 객체 생성- 모델의 각종 옵션(하이퍼 파라미터)을 설정한다.

# %%
dt_clf = DecisionTreeClassifier()

# %% [markdown]
# 모델 훈련 - 훈련이 다 끝나면, 학습된 모델이 Return 된다.

# %%
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## 테스트 데이터 예측

# %% [markdown]
# 예측할 때는 Feature만 넣어주기.<br>데스트 데이터의 차원과 훈련 데이터의 차원을 일치시켜야 한다.

# %%
pred = dt_clf.predict(X_test)
print(f"테스트 세트의 예측 결과 : {pred}")
# Out:
# 테스트 세트의 예측 결과 : [2 2 1 1 2 0 1 0 0 1 1 1 1 2 2 0 2 1 2 2 1 0 0 1 0 0 2 1 0 1]

# %% [markdown]
# ## 평가

# %% [markdown]
# 예측 정확도(Accuracy) 평가

# %%
from sklearn.metrics import accuracy_score

acc_result = accuracy_score(y_test,pred)
print(f"예측 정확도 : {acc_result :.4f}")
# Out:
# 예측 정확도 : 0.9333
